# %%
data = {
    "identity": "waleed@gmail.com",
    "name": "Waleed",
    "room": "room_waleed@gmail.com",
    "course_details": {
  "course": {
    "id": 7,
    "name": "Idiopathic Parkinson’s Disease",
    "start_date": "2025-06-30",
    "duration": 14,
    "patient_history": "Primary Diagnosis: Idiopathic Parkinson’s Disease (diagnosed March 2023) – a progressive neurodegenerative disorder characterized primarily by motor symptoms including bradykinesia, tremor, and rigidity. \n Key Milestones: \n ● 2019: Patient first noticed a subtle resting tremor in the right hand, particularly during periods of inactivity or stress. \n ● Mid-2021: Mild rigidity and bradykinesia developed, affecting fine motor tasks like buttoning shirts and writing. \n ● July 2023: Initiated on low-dose Levodopa therapy in response to increasing motor symptoms; good initial response reported. \n ● Neurological Assessment: No signs of atypical Parkinsonism. \n ● Genetic/Family History: No known familial history of Parkinson’s disease or other movement disorders. \n Comorbid Conditions: \n ● Hypertension: Diagnosed in 2018; currently managed with Amlodipine. \n ● Type 2 Diabetes Mellitus: Diagnosed in 2020; under control with Metformin and lifestyle modification. \n ● Sleep disturbances and occasional mood fluctuations have also been observed over the past year, likely associated with PD progression.",
    "current_situation": "Symptoms Logged (Last 7 Days): \n ● Average tremor severity: 3/5 \n ● “Off” periods: Occur twice daily, each lasting approximately 30 minutes, usually around late morning and early evening. \n ● Bradykinesia episodes: Noted in morning hours, causing difficulty in initiating movements. \n ● Gait instability: Mild shuffling noted, especially in confined spaces. \n ● Fall count: 1 (slip in bathroom, no major injury reported) \n ● Sleep disturbances: Reported waking up 2-3 times during the night due to stiffness. \n ● Mood: Occasional irritability and low mood, particularly during off periods. \n ● Medication adherence: 96% (missed one evening dose due to drowsiness)",
    "doctor_instructions": "● Avoid using stairs without support; always use handrails or assistance. \n ● Install grab bars in the bathroom and near the bed for fall prevention. \n ● Do not consume processed or high-fat fast foods; maintain a fiber-rich and diabetic-friendly diet. \n ● Avoid sudden posture changes (like quickly standing up) to prevent dizziness. \n ● Engage in light stretching and physiotherapy exercises daily. \n ● Keep a daily symptom journal to help track off periods, mood changes, and medication response. \n ● Avoid activities requiring fine motor control (e.g., handling knives) during tremor peaks. \n ● Limit screen time before bed to help reduce sleep disturbances. \n ● Encourage routine social interaction to help prevent isolation-related depression.",
    "created_at": "2025-06-30T09:25:32.314463Z",
    "is_active": True
  },
  "medicines": [
    {
      "id": 12,
      "name": "Levodopa",
      "description": "Used for Parkinson’s symptoms. Take with food to reduce nausea.",
      "is_active": True
    },
    {
      "id": 13,
      "name": "Rasagiline",
      "description": "Take on an empty stomach, avoid tyramine-rich foods.",
      "is_active": True
    },
    {
      "id": 14,
      "name": "Olmesartan",
      "description": "Used for hypertension. Take with food to reduce nausea.",
      "is_active": True
    },
    
  ],
  "schedules": [
    {
      "id": 21,
      "medicine_id": 12,
      "medicine_name": "Levodopa",
      "medicine_description": None,
      "time": "08:00:00",
      "dosage": "150mg",
      "is_active": True,
      "taken": False
    },
    {
      "id": 29,
      "medicine_id": 17,
      "medicine_name": "Olmesartan",
      "medicine_description": None,
      "time": "08:00:00",
      "dosage": "220mg",
      "is_active": True,
      "taken": False
    },
    {
      "id": 22,
      "medicine_id": 12,
      "medicine_name": "Levodopa",
      "medicine_description": None,
      "time": "16:00:00",
      "dosage": "150mg",
      "is_active": True,
      "taken": False
    },
    
  ],
  "next_schedules": [
    {
      "id": 21,
      "medicine_id": 12,
      "medicine_name": "Levodopa",
      "medicine_description": None,
      "time": "08:00:00",
      "dosage": "150mg",
      "is_active": True,
      "taken": False
    }
  ]
}
}

# %%
# server.py
import os
from livekit import api
from dotenv import load_dotenv
import json
load_dotenv()

def getToken():
  token = api.AccessToken(os.getenv('LIVEKIT_API_KEY'), os.getenv('LIVEKIT_API_SECRET')) \
    .with_identity(data['identity']) \
    .with_name(data['name']) \
    .with_metadata(json.dumps(data['course_details'])) \
    .with_grants(api.VideoGrants(
        room_join=True,
        room=data['room']
    ))
  return token.to_jwt()

# %%
print(getToken())
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..DFBONkuZxdFzfwtkizr81EKgn4ASV5_6SolkXk0ASrg

# %%
import json

def generate_kindura_prompt(backend_data_json):
    data = json.loads(backend_data_json)

    course = data["result"]["course"]
    medicines = data["result"]["medicines"]
    schedules = data["result"]["schedules"]
    next_schedules = data["result"]["next_schedules"]

    patient_history = course["patient_history"]
    current_situation = course["current_situation"]
    doctor_instructions = course["doctor_instructions"]

    # Emergency contacts from backend JSON or default if not present
    emergency_contacts = data["result"].get("emergency_contacts", {
        "caregiver_name": "Caregiver",
        "caregiver_phone": "N/A",
        "doctor_name": "Doctor",
        "doctor_phone": "N/A",
        "helpline_name": "National Health Helpline",
        "helpline_phone": "+1-800-111-2222"
    })

    # Location-dependent variables from backend JSON or default if not present
    location_data = data["result"].get("location_data", {
        "timezone": "UTC",
        "local_emergency_number": "911",
        "country_code": "US"
    })

    # Read the template file
    with open("utils/kindura_prompt_template.txt", "r") as f:
        template = f.read()

    medication_info_str = ""
    for med in medicines:
        medication_info_str += f"- {med.get('name', 'Unknown Medicine')}: {med.get('description', 'No description provided.')}\n"

    medication_schedule_str = ""
    for sched in schedules:
        medication_schedule_str += f"- {sched.get('medicine_name', 'Unknown Medicine')} ({sched.get('dosage', 'N/A')}) at {sched.get('time', 'N/A')}. Instructions: {sched.get('medicine_description', 'No specific instructions.')}\n"

    # Fill the template with dynamic content
    generated_prompt = template.format(
        patient_history=patient_history,
        current_situation=current_situation,
        doctor_instructions=doctor_instructions,
        medication_info=medication_info_str,
        medication_schedule=medication_schedule_str,
        caregiver_name=emergency_contacts.get("caregiver_name", "Caregiver"),
        caregiver_phone=emergency_contacts.get("caregiver_phone", "N/A"),
        doctor_name=emergency_contacts.get("doctor_name", "Doctor"),
        doctor_phone=emergency_contacts.get("doctor_phone", "N/A"),
        helpline_name=emergency_contacts.get("helpline_name", "National Health Helpline"),
        helpline_phone=emergency_contacts.get("helpline_phone", "+1-800-111-2222"),
        timezone=location_data.get("timezone", "UTC"),
        local_emergency_number=location_data.get("local_emergency_number", "911"),
        country_code=location_data.get("country_code", "US")
    )

    return generated_prompt

if __name__ == "__main__":
    # This is a placeholder for the actual backend JSON data
    backend_json_data = json.dumps({
    "status": True,
    "result": {
        "course": {
            "id": 7,
            "name": "Type 1 Diabetes Management",
            "start_date": "2025-01-15",
            "duration": 365,
            "patient_history": "Primary Diagnosis: Type 1 Diabetes Mellitus (diagnosed January 2020) – an autoimmune condition requiring daily insulin injections.\nKey Milestones:\n● 2020: Diagnosed with T1D, initiated on insulin therapy (basal-bolus regimen).\n● 2021-2024: Consistent blood glucose monitoring and insulin adjustments. Occasional hypoglycemic episodes, managed with glucose tablets.\n● Neurological Assessment: No significant neuropathy reported.\n● Genetic/Family History: Mother has Type 2 Diabetes, no family history of Type 1.\nComorbid Conditions:\n● None significant.",
            "current_situation": "Symptoms Logged (Last 7 Days):\n● Average blood glucose: 140 mg/dL (target 80-130 mg/dL)\n● Hypoglycemic episodes: 2 (mild, self-managed)\n● Hyperglycemic episodes: 1 (after a high-carb meal, corrected with insulin)\n● Energy levels: Generally good, occasional fatigue in the afternoon.\n● Mood: Stable.\n● Medication adherence: 100% (all insulin doses taken as prescribed)",
            "doctor_instructions": "● Continue daily blood glucose monitoring.\n● Adjust insulin doses based on carbohydrate intake and activity levels.\n● Carry glucose tablets at all times for hypoglycemic episodes.\n● Engage in regular physical activity (at least 30 minutes daily).\n● Maintain a balanced diet, focusing on complex carbohydrates and lean proteins.\n● Monitor for signs of neuropathy or retinopathy during annual check-ups.",
            "created_at": "2025-01-10T10:00:00.000000Z",
            "is_active": True
        },
        "medicines": [
            {
                "id": 1,
                "name": "Insulin Glargine (Lantus)",
                "description": "Long-acting insulin, take once daily at bedtime.",
                "is_active": True
            },
            {
                "id": 2,
                "name": "Insulin Lispro (Humalog)",
                "description": "Rapid-acting insulin, take before meals based on carb count.",
                "is_active": True
            }
        ],
        "schedules": [
            {
                "id": 1,
                "medicine_id": 1,
                "medicine_name": "Insulin Glargine (Lantus)",
                "medicine_description": "Long-acting insulin, take once daily at bedtime.",
                "time": "22:00:00",
                "dosage": "20 units",
                "is_active": True,
                "taken": False
            },
            {
                "id": 2,
                "medicine_name": "Insulin Lispro (Humalog)",
                "medicine_description": "Rapid-acting insulin, take before meals based on carb count.",
                "time": "08:00:00",
                "dosage": "variable",
                "is_active": True,
                "taken": False
            }
        ],
        "next_schedules": [
            {
                "id": 3,
                "medicine_id": 2,
                "medicine_name": "Insulin Lispro (Humalog)",
                "medicine_description": "Rapid-acting insulin, take before meals based on carb count.",
                "time": "12:30:00",
                "dosage": "variable",
                "is_active": True,
                "taken": False
            }
        ],
        "emergency_contacts": {
            "caregiver_name": "Sarah",
            "caregiver_phone": "+1-555-123-4567",
            "doctor_name": "Dr. Emily White",
            "doctor_phone": "+1-555-987-6543",
            "helpline_name": "Diabetes Hotline",
            "helpline_phone": "+1-800-342-2383"
        },
        "location_data": {
            "timezone": "America/New_York",
            "local_emergency_number": "911",
            "country_code": "US"
        }
    }
})

    generated_prompt = generate_kindura_prompt(backend_json_data)
    with open("utils/kindura_ai_prompt.txt", "w") as f:
        f.write(generated_prompt)
    print("Prompt generated and saved to kindura_ai_prompt.txt")
# Out:
# Prompt generated and saved to kindura_ai_prompt.txt

# %%
generated_prompt
# Out:
# ''

# %%
from utils.json_to_be import upload_json

def print_response(response, context):
    print(f"[{context}] Status: {response.status_code}, Response: {response.text}")


upload_json("user_logs/transcript_test001@gmail.com_20250704_014235.json", "http://localhost:8000/api", "Token vaDJ6pRIYzxpl3gHyF8K6_GykZ412Xqtig60Mr1fFj0", print_response)
# Out:
# Uploading transcript JSON: user_logs/transcript_waleed@gmail.com_20250703_190735.json
# [Upload JSON File] Status: 201, Response: {"status":true,"result":{"id":12,"status":"pending","uploaded_at":"2025-07-07T18:07:10.069127Z","message":"JSON uploaded successfully. Processing started in background."}}
# ✅ Upload JSON successful!
# True
